# %%
for x in {1,2,3,4}:
    print(x,end=" ")
# Out:
# 1 2 3 4

# %%
my_list=[13,4,5,6]
my_iter=iter(my_list)

# %%
my_iter

# %%
next(my_iter)
# Out:
# 13

# %%
next(my_iter)
# Out:
# 4

# %%
next(my_iter)
# Out:
# 5

# %%
next(my_iter)
# Out:
# 6

# %%
next(my_iter)# because nothing is left
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 next(my_iter)
#
# StopIteration:

# %% [markdown]
# ![image.png](attachment:a101ab33-06fc-4e38-8bf5-05f3c064c8c1.png)
