# %% [markdown]
# modular programminng refers to the process of breaking a large progrmming tasks into separate ,smaller , more managemable subtasks
# advanatges:
# 1.simplicity
# 2.maintainabilty
# 3.reusability
# 4.scoping

# %% [markdown]
# ### functions , modules and packages are all constrcuts in python that promote code modulariztion

# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\hp\OneDrive\codes\python

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'basics.ipynb', 'Data Types.ipynb', 'functions_python.ipynb', 'iterator.ipynb', 'modules_python.ipynb', "OOP's.ipynb", 'task tracker.ipynb']

# %%
os.mkdir("temp")

# %%
## we made our very own modules in python
import my_calculator as calc

# %%
# from my_calculator import * to import all fucntions
# from my_calculator imporrt add to import only additon functions
# from my_calculator import sub,add tom import addition and subtraction functions

# %%
a=20
b=30
print(calc.add(a,b))
# Out:
# 50

# %%
calc.mod(a,b)
# Out:
# 20

# %%
calc.div(a,b)
# Out:
# 0.6666666666666666

# %%
dir(calc) #list all the function(in-built and user defined functions) from the directory
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'div',
#  'mod',
#  'mul',
#  'sub']

# %% [markdown]
# ![image.png](attachment:d448615b-411d-46e3-8f0e-1d096b82bdbf.png)

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\hp\\OneDrive\\codes\\python',
#  'C:\\ProgramData\\anaconda3\\python311.zip',
#  'C:\\ProgramData\\anaconda3\\DLLs',
#  'C:\\ProgramData\\anaconda3\\Lib',
#  'C:\\ProgramData\\anaconda3',
#  '',
#  'C:\\Users\\hp\\AppData\\Roaming\\Python\\Python311\\site-packages',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
import numpy

# %%
import pandas

# %%
import matplotlib
