# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("bank_marketing_updated_v1.csv",skiprows=2)
df
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
df.drop("customerid",axis=1,inplace=True)
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...

# %%
df["job"]=df["jobedu"].apply(lambda x:x.split(",")[0])

# %%
df["educaton"]=df["jobedu"].apply(lambda x:x.split(",")[1])

# %%
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job   educaton
# ...

# %%
df.drop("jobedu",axis=1,inplace=True)
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             job   educaton
# 0    management   tertiary
# 1    technician  secondary
# ...

# %%
df["response"].isnull().sum()/df.shape[0]
# Out:
# 0.000663555329455221

# %%
df["salary"].astype(float).mean()
df["salary"].astype(float).quantile(0.75)
# Out:
# 70000.0

# %%
import seaborn as sns
sns.boxplot(df["salary"])
# Out:
# <Axes: ylabel='salary'>

# %%
df["duration"].dtype
# Out:
# dtype('O')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset (tips dataset)
df = sns.load_dataset('tips')

### UNIVARIATE ANALYSIS ###

# 1. Histogram (Univariate for 'total_bill')
plt.figure(figsize=(8, 6))
plt.hist(df['total_bill'], bins=10, color='skyblue')
plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# 2. Boxplot (Univariate for 'total_bill')
plt.figure(figsize=(8, 6))
sns.boxplot(df['total_bill'])
plt.title('Boxplot of Total Bill')
plt.show()

# 3. Barplot (Univariate for 'day' count)
plt.figure(figsize=(8, 6))
sns.countplot(x='day', data=df)
plt.title('Barplot of Days')
plt.show()

# 4. Pie Chart (Univariate for 'smoker' category)
plt.figure(figsize=(8, 6))
df['smoker'].value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
plt.title('Pie Chart of Smoker Category')
plt.ylabel('')  # Remove the y-label
plt.show()


### BIVARIATE ANALYSIS ###

# 5. Boxplot (Bivariate - Total Bill by Day)
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Boxplot of Total Bill by Day')
plt.show()

# 6. Violin Plot (Bivariate - Total Bill by Time)
plt.figure(figsize=(8, 6))
sns.violinplot(x='time', y='total_bill', data=df)
plt.title('Violin Plot of Total Bill by Time')
plt.show()

# 7. Scatter Plot (Bivariate - Total Bill vs Tip)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.title('Scatter Plot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# 8. Pair Plot (Bivariate Relationships for Numeric Columns)
sns.pairplot(df)
plt.suptitle('Pair Plot of Numeric Variables', y=1.02)
plt.show()

# 9. Heatmap (Bivariate Correlation Matrix for Numeric Columns)
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of Correlation Matrix (Numeric Variables Only)')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset (tips dataset)
df = sns.load_dataset('tips')

# Regplot for multivariate analysis: Total Bill vs Tip with Smoker as hue
plt.figure(figsize=(8, 6))
sns.regplot(x='total_bill', y='tip', data=df, scatter_kws={'color':'skyblue'}, line_kws={'color':'black'})
plt.title('Regplot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# Another way: Introducing a third variable with 'hue' in a lmplot (for categorical data)
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=df, aspect=1.5)
plt.title('Regplot with Hue (Smoker vs Non-Smoker)')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv("bank_marketing_updated_v1.csv",skiprows=2)
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
df["job"] = df["jobedu"].apply(lambda x : x.split(",")[0])
df["education"] = df["jobedu"].apply(lambda x : x.split(",")[1])

# %%
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  ... day      month duration campaign  pdays  \
# 0      yes      no     yes   no  ...   5  may, 2017  261 sec        1     -1
# 1      yes      no     yes   no  ...   5  may, 2017  151 sec        1     -1
# 2      yes      no     yes  yes  ...   5  may, 2017   76 sec        1     -1
# 3       no      no     yes   no  ...   5  may, 2017   92 sec        1     -1
# 4       no      no      no   no  ...   5  may, 2017  198 sec        1     -1
#
#    previous  poutcome response           job  education
# ...

# %%
df.groupby("education")["salary"].aggregate(["mean","median"])
# Out:
#                    mean    median
# education
# primary    34212.377755   20000.0
# secondary  49743.815188   55000.0
# tertiary   82873.618525  100000.0
# unknown    46558.427571   50000.0

# %%
df["response"].dtype
# Out:
# dtype('O')

# %%
df["response_codes"] = df["response"].apply(lambda x: 1 if isinstance(x, str) and x.lower() == "yes" else 0)

# %%
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  ...      month  duration campaign pdays  \
# 0      yes      no     yes   no  ...  may, 2017   261 sec        1    -1
# 1      yes      no     yes   no  ...  may, 2017   151 sec        1    -1
# 2      yes      no     yes  yes  ...  may, 2017    76 sec        1    -1
# 3       no      no     yes   no  ...  may, 2017    92 sec        1    -1
# 4       no      no      no   no  ...  may, 2017   198 sec        1    -1
#
#    previous  poutcome  response           job  education response_codes
# ...

# %%
df.groupby("education")["response_codes"].mean()
# Out:
# education
# primary      0.086265
# secondary    0.105551
# tertiary     0.149989
# unknown      0.135703
# Name: response_codes, dtype: float64

# %%
df["response_codes"].value_counts()
# Out:
# response_codes
# 0    39924
# 1     5287
# Name: count, dtype: int64

# %%
df["response"].value_counts()
# Out:
# response
# no     39894
# yes     5287
# Name: count, dtype: int64

# %%
df["response_flags"] = np.where(df.response=="yes",1,0) # np.where is designed to handle situations hwere value are not string

# %%
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  ... duration  campaign pdays previous  \
# 0      yes      no     yes   no  ...  261 sec         1    -1        0
# 1      yes      no     yes   no  ...  151 sec         1    -1        0
# 2      yes      no     yes  yes  ...   76 sec         1    -1        0
# 3       no      no     yes   no  ...   92 sec         1    -1        0
# 4       no      no      no   no  ...  198 sec         1    -1        0
#
#    poutcome  response           job  education response_codes response_flags
# ...

# %%
df["response"].value_counts(normalize=True)
# Out:
# response
# no     0.882982
# yes    0.117018
# Name: proportion, dtype: float64

# %%
df.groupby("job")["response_flags"].value_counts(normalize=True)
# Out:
# job            response_flags
# admin.         0                 0.878167
#                1                 0.121833
# blue-collar    0                 0.927250
#                1                 0.072750
# entrepreneur   0                 0.917283
#                1                 0.082717
# housemaid      0                 0.912097
#                1                 0.087903
# management     0                 0.862444
#                1                 0.137556
# retired        0                 0.772085
#                1                 0.227915
# self-employed  0                 0.882204
#                1                 0.117796
# services       0                 0.911170
#                1                 0.088830
# student        0                 0.713220
#                1                 0.286780
# technician     0                 0.889430
#                1                 0.110570
# unemployed     0                 0.844973
#                1                 0.155027
# ...
