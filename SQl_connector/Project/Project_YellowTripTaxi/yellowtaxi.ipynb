# %% [markdown]
# <a href="https://colab.research.google.com/github/swayam-learning/DataScience_ML/blob/master/Project/Project_YellowTripTaxi/yellowtaxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 30) ## sare column dekhne ke liye
pd.set_option('display.max_rows', 50) ##ab column dekh rahe hai toh row bhi dekhle yaar
pd.options.display.float_format = '{:.2f}'.format ## bhai pareshan ho gaya exponential se toh yahi tareeka hai

# %% [markdown]
# - **VendorID**
#   Code indicating the TPEP (Taxi Passenger Enhancement Program) provider that supplied the record.
#   - `1` = Creative Mobile Technologies, LLC
#   - `2` = VeriFone Inc.
#
# - **tpep_pickup_datetime**
#   The date and time when the meter was engaged.
#
# - **tpep_dropoff_datetime**
#   The date and time when the meter was disengaged.
#
# - **Passenger_count**
#   The number of passengers in the vehicle.
#   _(Note: This value is entered manually by the driver.)_
#
# - **Trip_distance**
#   The total trip distance in miles, as reported by the taximeter.
#
# - **PULocationID**
#   TLC Taxi Zone ID where the meter was engaged.
#
# - **DOLocationID**
#   TLC Taxi Zone ID where the meter was disengaged.
#
# - **RateCodeID**
#   The final rate code applied at the end of the trip.
#   - `1` = Standard rate
#   - `2` = JFK Airport
#   - `3` = Newark Airport
#   - `4` = Nassau or Westchester
#   - `5` = Negotiated fare
#   - `6` = Group ride
#
# - **Store_and_fwd_flag**
#   Indicates if the trip record was held in vehicle memory before being sent to the server.
#   - `Y` = Store and forward trip
#   - `N` = Not a store and forward trip
#
# - **Payment_type**
#   Numeric code representing how the passenger paid for the trip.
#   - `1` = Credit card
#   - `2` = Cash
#   - `3` = No charge
#   - `4` = Dispute
#   - `5` = Unknown
#   - `6` = Voided trip
#
# - **Fare_amount**
#   The base fare calculated based on time and distance by the meter.
#
# - **Extra**
#   Additional surcharges, such as rush hour and overnight charges ($0.50 and $1, respectively).
#
# - **MTA_tax**
#   A $0.50 tax automatically triggered based on the metered rate.
#
# - **Improvement_surcharge**
#   A $0.30 surcharge levied at the start of each trip, starting in 2015.
#
# - **Tip_amount**
#   Tips recorded automatically for credit card transactions. _(Cash tips are not included.)_
#
# - **Tolls_amount**
#   The total amount of tolls paid during the trip.
#
# - **Total_amount**
#   The total fare charged to passengers, excluding cash tips.
#
# - **Congestion_Surcharge**
#   The total amount collected for the NYS congestion surcharge during the trip.

# %% [markdown]
# # **Cleaning**

# %%
df = pd.read_csv('https://query.data.world/s/sojjjcx7g7ll2cixc7ir2yvgvrrfh6?dws=00000')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0      1.00  2020-01-01 00:28:15   2020-01-01 00:33:03             1.00
# 1      1.00  2020-01-01 00:35:39   2020-01-01 00:43:04             1.00
# 2      1.00  2020-01-01 00:47:41   2020-01-01 00:53:52             1.00
# 3      1.00  2020-01-01 00:55:23   2020-01-01 01:00:14             1.00
# 4      2.00  2020-01-01 00:01:58   2020-01-01 00:04:16             1.00
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.20        1.00                  N           238           239
# 1           1.20        1.00                  N           239           238
# 2           0.60        1.00                  N           238           238
# 3           0.80        1.00                  N           238           151
# 4           0.00        1.00                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          1.00         6.00   3.00     0.50        1.47          0.00
# 1          1.00         7.00   3.00     0.50        1.50          0.00
# 2          1.00         6.00   3.00     0.50        1.00          0.00
# 3          1.00         5.50   0.50     0.50        1.36          0.00
# 4          2.00         3.50   0.50     0.50        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                   0.30         11.27                  2.50
# 1                   0.30         12.30                  2.50
# 2                   0.30         10.80                  2.50
# 3                   0.30          8.16                  0.00
# 4                   0.30          4.80                  0.00

# %%
df.info(memory_usage="deep",verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6405008 entries, 0 to 6405007
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           float64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: float64(13), int64(2), object(3)
# memory usage: 2.0 GB

# %% [markdown]
# ## **Finding the percentage of null values**

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# VendorID                1.02
# tpep_pickup_datetime    0.00
# tpep_dropoff_datetime   0.00
# passenger_count         1.02
# trip_distance           0.00
# RatecodeID              1.02
# store_and_fwd_flag      1.02
# PULocationID            0.00
# DOLocationID            0.00
# payment_type            1.02
# fare_amount             0.00
# extra                   0.00
# mta_tax                 0.00
# tip_amount              0.00
# tolls_amount            0.00
# improvement_surcharge   0.00
# total_amount            0.00
# congestion_surcharge    0.00
# dtype: float64

# %% [markdown]
# ### *as most of the columns have only 1% null values we can drop them as it won't effect the overall dataset*

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### *we have dropped the null values*

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## *no we do not have null values or duplicate values*

# %% [markdown]
# ## *checking for the integrity of data in the numerical columns*

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0      1.00  2020-01-01 00:28:15   2020-01-01 00:33:03             1.00
# 1      1.00  2020-01-01 00:35:39   2020-01-01 00:43:04             1.00
# 2      1.00  2020-01-01 00:47:41   2020-01-01 00:53:52             1.00
# 3      1.00  2020-01-01 00:55:23   2020-01-01 01:00:14             1.00
# 4      2.00  2020-01-01 00:01:58   2020-01-01 00:04:16             1.00
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.20        1.00                  N           238           239
# 1           1.20        1.00                  N           239           238
# 2           0.60        1.00                  N           238           238
# 3           0.80        1.00                  N           238           151
# 4           0.00        1.00                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          1.00         6.00   3.00     0.50        1.47          0.00
# 1          1.00         7.00   3.00     0.50        1.50          0.00
# 2          1.00         6.00   3.00     0.50        1.00          0.00
# 3          1.00         5.50   0.50     0.50        1.36          0.00
# 4          2.00         3.50   0.50     0.50        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                   0.30         11.27                  2.50
# 1                   0.30         12.30                  2.50
# 2                   0.30         10.80                  2.50
# 3                   0.30          8.16                  0.00
# 4                   0.30          4.80                  0.00

# %%
df[df["fare_amount"]<0].sort_values("total_amount")
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 471400       2.00  2020-01-03 19:29:51   2020-01-05 12:28:15             1.00
# 3938141      2.00  2020-01-21 01:10:40   2020-01-21 01:10:49             4.00
# 1024291      2.00  2020-01-06 22:23:17   2020-01-06 22:23:30             1.00
# 2724419      2.00  2020-01-15 05:00:34   2020-01-15 05:04:39             1.00
# 5227053      2.00  2020-01-26 21:47:20   2020-01-26 21:48:25             1.00
# ...           ...                  ...                   ...              ...
# 5187669      2.00  2020-01-26 17:30:27   2020-01-26 17:30:55             1.00
# 5052402      2.00  2020-01-26 00:08:11   2020-01-26 00:08:15             1.00
# 260630       2.00  2020-01-02 16:34:56   2020-01-02 16:35:02             1.00
# 348971       1.00  2020-01-03 07:49:34   2020-01-03 07:54:34             1.00
# 2405463      1.00  2020-01-13 15:58:03   2020-01-13 16:50:13             1.00
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 471400            8.27        1.00                  N           186
# 3938141           0.00        5.00                  N            42
# 1024291           0.00        5.00                  N            65
# 2724419           0.00        5.00                  N           133
# 5227053           0.02        5.00                  N           186
# ...                ...         ...                ...           ...
# 5187669           0.00        5.00                  N           193
# 5052402           0.00        5.00                  N           264
# 260630            0.00        5.00                  N           135
# 348971            0.00        1.00                  N            75
# 2405463           0.00        1.00                  N           125
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 471400            152          3.00     -1238.00  -1.00    -0.50        0.00
# 3938141            42          4.00      -730.00   0.00     0.00        0.00
# 1024291            65          2.00      -500.00   0.00     0.00        0.00
# 2724419           133          3.00      -400.00   0.00     0.00        0.00
# 5227053           186          3.00      -330.00   0.00    -0.50        0.00
# ...               ...           ...          ...    ...      ...         ...
# 5187669           193          3.00        -0.05   0.00     0.00        0.00
# 5052402           264          3.00        -0.02   0.00     0.00        0.00
# 260630            135          3.00        -0.01   0.00     0.00        0.00
# 348971             75          1.00        -0.80   0.00     0.50        0.00
# 2405463           196          1.00        -0.80   0.00     0.50        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 471400           0.00                  -0.30      -1242.30
# 3938141          0.00                  -0.30       -730.30
# 1024291          0.00                  -0.30       -500.30
# 2724419          0.00                  -0.30       -400.30
# 5227053          0.00                  -0.30       -333.30
# ...               ...                    ...           ...
# 5187669          0.00                  -0.30         -0.35
# 5052402          0.00                  -0.30         -0.32
# 260630           0.00                  -0.30         -0.31
# 348971           0.00                   0.30          0.00
# 2405463          6.12                   0.30          6.12
#
#          congestion_surcharge
# 471400                  -2.50
# 3938141                  0.00
# 1024291                  0.00
# 2724419                  0.00
# 5227053                 -2.50
# ...                       ...
# 5187669                  0.00
# 5052402                  0.00
# 260630                   0.00
# 348971                   0.00
# 2405463                  0.00
#
# [19441 rows x 18 columns]

# %% [markdown]
# ### *the amount paid can never be negative i am going to change it to positive and then find out if there is any anomaly*

# %%
for col in list(df.select_dtypes(include="number").columns):
    df[col] = df[col].apply(lambda x: abs(x))

# %% [markdown]
# ### *Cross validating if the loop worked*

# %%
df[df["fare_amount"]<0].sort_values("total_amount")
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %% [markdown]
# ### *Making the columns have correct datatypes*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339567 entries, 0 to 6339566
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           float64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: float64(13), int64(2), object(3)
# memory usage: 919.0+ MB

# %%
df["tpep_dropoff_datetime"] = df["tpep_dropoff_datetime"].astype("datetime64[ns]")
df["tpep_pickup_datetime"] = df["tpep_pickup_datetime"].astype("datetime64[ns]")

# %%
df["payment_type"].value_counts()
# Out:
# payment_type
# 1.00    4694897
# 2.00    1593834
# 3.00      32770
# 4.00      18065
# 5.00          1
# Name: count, dtype: int64

# %% [markdown]
# ### *we see that the payment type has only 5 modes of payment we can convert this to int*

# %%
df["payment_type"] = df["payment_type"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339567 entries, 0 to 6339566
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: datetime64[ns](2), float64(12), int64(3), object(1)
# memory usage: 919.0+ MB

# %%
df["tpep_pickup_datetime"].value_counts()
# Out:
# tpep_pickup_datetime
# 2020-01-16 18:53:03    16
# 2020-01-28 18:18:25    16
# 2020-01-14 18:42:52    15
# 2020-01-14 07:53:28    15
# 2020-01-13 22:17:54    15
#                        ..
# 2020-01-05 21:22:06     1
# 2020-01-19 01:01:22     1
# 2020-01-11 08:17:43     1
# 2020-01-19 01:18:21     1
# 2020-02-01 00:00:37     1
# Name: count, Length: 2129013, dtype: int64

# %%
df['VendorID'] = df['VendorID'].astype('category')
df['RatecodeID'] = df['RatecodeID'].astype('category')
df['store_and_fwd_flag'] = df['store_and_fwd_flag'].astype('category')
df['PULocationID'] = df['PULocationID'].astype('category')
df['DOLocationID'] = df['DOLocationID'].astype('category')
df["passenger_count"] = df["passenger_count"].astype("int")

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6339567 entries, 0 to 6339566
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               category
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   RatecodeID             category
#  6   store_and_fwd_flag     category
#  7   PULocationID           category
#  8   DOLocationID           category
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: category(5), datetime64[ns](2), float64(9), int64(2)
# memory usage: 719.5 MB

# %% [markdown]
# ### *the memory usage dropped from 2.0 gb to 885.9 MB*

# %% [markdown]
# ### *want to work only on dates in the month of january*

# %%
df = df[(df["tpep_dropoff_datetime"]>"2020-01-01 00:00:00") & (df["tpep_dropoff_datetime"]<"2020-01-31 23:59:59")]

# %%
df.tpep_pickup_datetime.describe()
# Out:
# count                          6336742
# mean     2020-01-17 03:52:53.983592448
# min                2019-12-31 14:15:51
# 25%                2020-01-09 17:38:49
# 50%                2020-01-17 00:07:36
# 75%                2020-01-24 18:32:48
# max                2020-01-31 23:59:07
# Name: tpep_pickup_datetime, dtype: object

# %%
df.describe()
# Out:
#                 tpep_pickup_datetime          tpep_dropoff_datetime  \
# count                        6336742                        6336742
# mean   2020-01-17 03:52:53.983592448  2020-01-17 04:08:38.059139840
# min              2019-12-31 14:15:51            2020-01-01 00:00:47
# 25%              2020-01-09 17:38:49            2020-01-09 17:54:52
# 50%              2020-01-17 00:07:36            2020-01-17 00:24:00
# 75%              2020-01-24 18:32:48            2020-01-24 18:48:31
# max              2020-01-31 23:59:07            2020-01-31 23:59:58
# std                              NaN                            NaN
#
#        passenger_count  trip_distance  payment_type  fare_amount      extra  \
# count       6336742.00     6336742.00    6336742.00   6336742.00 6336742.00
# mean              1.52           2.85          1.27        12.57       1.10
# min               0.00           0.00          1.00         0.00       0.00
# 25%               1.00           0.96          1.00         6.50       0.00
# 50%               1.00           1.60          1.00         9.00       0.50
# 75%               2.00           2.90          2.00        13.50       2.50
# max               9.00         262.88          5.00      4265.00     113.01
# std               1.15           3.76          0.47        11.87       1.25
#
#          mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# count 6336742.00  6336742.00    6336742.00             6336742.00
# mean        0.50        2.21          0.34                   0.30
# min         0.00        0.00          0.00                   0.00
# 25%         0.50        0.00          0.00                   0.30
# 50%         0.50        1.95          0.00                   0.30
# 75%         0.50        2.86          0.00                   0.30
# max        30.80     1100.00        910.50                   0.30
# std         0.04        2.76          1.75                   0.01
#
#        total_amount  congestion_surcharge
# count    6336742.00            6336742.00
# mean          18.56                  2.31
# min            0.00                  0.00
# 25%           11.16                  2.50
# 50%           14.16                  2.50
# 75%           19.56                  2.50
# max         4268.30                  2.75
# std           14.52                  0.66

# %%
df["date"] = df["tpep_pickup_datetime"].dt.date
df["day"] = df["tpep_pickup_datetime"].dt.day
df["month"] = df["tpep_pickup_datetime"].dt.month
df["year"] = df["tpep_pickup_datetime"].dt.year
df['hr'] = df['tpep_pickup_datetime'].dt.hour
df['weekday'] = df['tpep_pickup_datetime'].dt.weekday

# %%
df["duration_of_trip"] = df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]

# %%
df['duration_of_trip'] = df['duration_of_trip'] / np.timedelta64(1, 'm')
## this helps in converting them into proper minutes for example we have 00:30:00 now after divding it to timedelta64(1,"m") it will be converted to 30.0 as in minutes

# %%
df["duration_of_trip"].describe()
# Out:
# count   6336742.00
# mean         15.73
# std          62.53
# min       -2770.37
# 25%           6.33
# 50%          10.40
# 75%          16.65
# max        8525.12
# Name: duration_of_trip, dtype: float64

# %% [markdown]
# ### *we have negative values that means pickup time is greater than drop off time which is not possible*

# %%
df[df["duration_of_trip"]<0].sort_values(by="duration_of_trip")
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 540040     1.00  2020-01-04 08:19:55   2020-01-02 10:09:33                1
#
#         trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 540040           3.50       1.00                  N          107          237
#
#         payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 540040             1        16.50   2.50     0.50        4.95          0.00
#
#         improvement_surcharge  total_amount  congestion_surcharge        date  \
# 540040                   0.30         24.75                  2.50  2020-01-04
#
#         day  month  year  duration_of_trip
# 540040    4      1  2020          -2770.37

# %% [markdown]
# #### *dropping the negative duration*

# %%
df = df[df["duration_of_trip"]>0]

# %%
df.duration_of_trip.describe()
# Out:
# count   6332595.00
# mean         15.75
# std          62.54
# min           0.02
# 25%           6.35
# 50%          10.40
# 75%          16.65
# max        8525.12
# Name: duration_of_trip, dtype: float64

# %% [markdown]
# ### *we have no negative duration*

# %%
df.duration_of_trip.max()
# Out:
# 8525.116666666667

# %% [markdown]
# #### *we have a trip which took 8525 minutes and no negative or zeros in the duration now trying to find duration for trips greater than 3hrs*

# %%
df[df["duration_of_trip"]>180].sort_values(by="duration_of_trip",ascending=False)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 4049543     2.00  2020-01-21 15:38:33   2020-01-27 13:43:40                1
# 4704348     2.00  2020-01-24 14:19:18   2020-01-28 10:49:13                1
# 944735      2.00  2020-01-06 15:39:47   2020-01-09 13:07:47                1
# 2290066     2.00  2020-01-12 23:04:21   2020-01-15 15:05:15                1
# 5059294     2.00  2020-01-26 00:51:39   2020-01-28 07:18:59                1
# ...          ...                  ...                   ...              ...
# 4172994     2.00  2020-01-22 05:30:33   2020-01-22 08:32:19                1
# 4102671     2.00  2020-01-21 16:12:43   2020-01-21 19:14:24                2
# 87903       1.00  2020-01-01 12:43:45   2020-01-01 15:45:06                3
# 5928819     2.00  2020-01-30 11:47:02   2020-01-30 14:47:55                1
# 4347596     2.00  2020-01-22 22:32:54   2020-01-23 01:33:34                1
#
#          trip_distance RatecodeID store_and_fwd_flag PULocationID  \
# 4049543           1.57       1.00                  N          186
# 4704348           0.01       1.00                  N          207
# 944735            0.00      99.00                  N          264
# 2290066           0.17       1.00                  N          101
# 5059294          58.85       1.00                  N          132
# ...                ...        ...                ...          ...
# 4172994           1.93       1.00                  N          138
# 4102671           0.00       5.00                  N          132
# 87903            12.80       1.00                  N           48
# 5928819           0.00      99.00                  N          207
# 4347596          24.71       1.00                  N          132
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 4049543          152             2      4265.00   0.00     0.50        0.00
# 4704348          146             2         7.50   0.80     0.50        0.00
# 944735           193             2         2.50   0.80     0.50        0.00
# 2290066           19             2         2.50   0.00     0.50        0.00
# 5059294            7             2      1718.50   0.50     0.50        0.00
# ...              ...           ...          ...    ...      ...         ...
# 4172994          230             2        11.00   0.00     0.50        0.00
# 4102671          264             1        65.00   0.00     0.50        0.00
# 87903             48             2       102.50   2.50     0.50        0.00
# 5928819          146             2         2.50   0.80     0.50        0.00
# 4347596          228             2        66.00   1.30     0.50        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 4049543          0.00                   0.30       4268.30
# 4704348          0.00                   0.00          8.80
# 944735           0.00                   0.00          3.80
# 2290066          0.00                   0.30          3.30
# 5059294          0.00                   0.30       1722.30
# ...               ...                    ...           ...
# 4172994          0.00                   0.30         14.30
# 4102671          0.00                   0.00         65.50
# 87903            0.00                   0.30        105.80
# 5928819          0.00                   0.00          3.80
# 4347596          0.00                   0.00         67.80
#
#          congestion_surcharge        date  day  month  year  duration_of_trip
# 4049543                  2.50  2020-01-21   21      1  2020           8525.12
# 4704348                  0.00  2020-01-24   24      1  2020           5549.92
# 944735                   0.00  2020-01-06    6      1  2020           4168.00
# 2290066                  0.00  2020-01-12   12      1  2020           3840.90
# 5059294                  2.50  2020-01-26   26      1  2020           3267.33
# ...                       ...         ...  ...    ...   ...               ...
# 4172994                  2.50  2020-01-22   22      1  2020            181.77
# 4102671                  0.00  2020-01-21   21      1  2020            181.68
# 87903                    2.50  2020-01-01    1      1  2020            181.35
# 5928819                  0.00  2020-01-30   30      1  2020            180.88
# 4347596                  0.00  2020-01-22   22      1  2020            180.67
#
# [13372 rows x 23 columns]

# %% [markdown]
# #### *we have 13372 entries which are greater than 3hrs*

# %% [markdown]
# #### *we try to fix the duartion of trip to less than 3 or 3.5 hrs , because there is no way that 5539minutes trip would lead to a total amount of 8.8 dollars so there is a fault in taximeter*

# %%
df = df[df["duration_of_trip"]<200]

# %%
df.head()
# Out:
#   VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0     1.00  2020-01-01 00:28:15   2020-01-01 00:33:03                1
# 1     1.00  2020-01-01 00:35:39   2020-01-01 00:43:04                1
# 2     1.00  2020-01-01 00:47:41   2020-01-01 00:53:52                1
# 3     1.00  2020-01-01 00:55:23   2020-01-01 01:00:14                1
# 4     2.00  2020-01-01 00:01:58   2020-01-01 00:04:16                1
#
#    trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           1.20       1.00                  N          238          239
# 1           1.20       1.00                  N          239          238
# 2           0.60       1.00                  N          238          238
# 3           0.80       1.00                  N          238          151
# 4           0.00       1.00                  N          193          193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         6.00   3.00     0.50        1.47          0.00
# 1             1         7.00   3.00     0.50        1.50          0.00
# 2             1         6.00   3.00     0.50        1.00          0.00
# 3             1         5.50   0.50     0.50        1.36          0.00
# 4             2         3.50   0.50     0.50        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge        date  day  \
# 0                   0.30         11.27                  2.50  2020-01-01    1
# 1                   0.30         12.30                  2.50  2020-01-01    1
# 2                   0.30         10.80                  2.50  2020-01-01    1
# 3                   0.30          8.16                  0.00  2020-01-01    1
# 4                   0.30          4.80                  0.00  2020-01-01    1
#
#    month  year  duration_of_trip
# 0      1  2020              4.80
# 1      1  2020              7.42
# 2      1  2020              6.18
# 3      1  2020              4.85
# 4      1  2020              2.30

# %%
df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1    4533475
# 2     943518
# 3     249276
# 5     224504
# 6     131450
# 4     122995
# 0     114006
# 7         29
# 9         19
# 8         17
# Name: count, dtype: int64

# %% [markdown]
# #### *i guess 0 pasengers means when the driver went alone to any distance or there was manual entry by the driver any case we will try to fill the value with median value*

# %%
passenger_median_count = df[df["passenger_count"]!=0]["passenger_count"].median()

# %%
df["passenger_count"] = df["passenger_count"].apply(lambda x:passenger_median_count if x==0 else x)

# %%
df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1.00    4647481
# 2.00     943518
# 3.00     249276
# 5.00     224504
# 6.00     131450
# 4.00     122995
# 7.00         29
# 9.00         19
# 8.00         17
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0     1.00  2020-01-01 00:28:15   2020-01-01 00:33:03             1.00
# 1     1.00  2020-01-01 00:35:39   2020-01-01 00:43:04             1.00
# 2     1.00  2020-01-01 00:47:41   2020-01-01 00:53:52             1.00
# 3     1.00  2020-01-01 00:55:23   2020-01-01 01:00:14             1.00
# 4     2.00  2020-01-01 00:01:58   2020-01-01 00:04:16             1.00
#
#    trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           1.20       1.00                  N          238          239
# 1           1.20       1.00                  N          239          238
# 2           0.60       1.00                  N          238          238
# 3           0.80       1.00                  N          238          151
# 4           0.00       1.00                  N          193          193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         6.00   3.00     0.50        1.47          0.00
# 1             1         7.00   3.00     0.50        1.50          0.00
# 2             1         6.00   3.00     0.50        1.00          0.00
# 3             1         5.50   0.50     0.50        1.36          0.00
# 4             2         3.50   0.50     0.50        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge        date  day  \
# 0                   0.30         11.27                  2.50  2020-01-01    1
# 1                   0.30         12.30                  2.50  2020-01-01    1
# 2                   0.30         10.80                  2.50  2020-01-01    1
# 3                   0.30          8.16                  0.00  2020-01-01    1
# 4                   0.30          4.80                  0.00  2020-01-01    1
#
#    month  year  duration_of_trip
# 0      1  2020              4.80
# 1      1  2020              7.42
# 2      1  2020              6.18
# 3      1  2020              4.85
# 4      1  2020              2.30

# %% [markdown]
# #### *now focusing on trip distance*

# %%
df["trip_distance"].describe()
# Out:
# count   6319289.00
# mean          2.85
# std           3.75
# min           0.00
# 25%           0.96
# 50%           1.60
# 75%           2.90
# max         211.70
# Name: trip_distance, dtype: float64

# %% [markdown]
# #### *ab dekho aise hi ki minnimum distance is somewhere 0 which is kind of confusing lets look into it*

# %%
df[df["trip_distance"]==0]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 4           2.00  2020-01-01 00:01:58   2020-01-01 00:04:16             1.00
# 6           2.00  2020-01-01 00:39:25   2020-01-01 00:39:29             1.00
# 19          1.00  2020-01-01 00:25:39   2020-01-01 00:27:05             1.00
# 473         1.00  2020-01-01 00:31:06   2020-01-01 01:04:57             1.00
# 646         1.00  2020-01-01 00:44:35   2020-01-01 01:16:02             1.00
# ...          ...                  ...                   ...              ...
# 6339382     2.00  2020-01-31 23:04:47   2020-01-31 23:04:57             4.00
# 6339401     2.00  2020-01-31 23:17:48   2020-01-31 23:17:51             5.00
# 6339436     1.00  2020-01-31 23:51:05   2020-01-31 23:51:08             1.00
# 6339508     1.00  2020-01-31 23:14:54   2020-01-31 23:15:57             1.00
# 6339566     2.00  2020-01-31 23:19:37   2020-01-31 23:20:41             1.00
#
#          trip_distance RatecodeID store_and_fwd_flag PULocationID  \
# 4                 0.00       1.00                  N          193
# 6                 0.00       1.00                  N          193
# 19                0.00       1.00                  N          170
# 473               0.00       1.00                  N          166
# 646               0.00       1.00                  N           17
# ...                ...        ...                ...          ...
# 6339382           0.00       5.00                  N          229
# 6339401           0.00       5.00                  N          263
# 6339436           0.00       1.00                  N          132
# 6339508           0.00       1.00                  N          132
# 6339566           0.00       1.00                  N          193
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 4                193             2         3.50   0.50     0.50        0.00
# 6                193             1         2.50   0.50     0.50        0.01
# 19               162             4         3.00   3.00     0.50        0.00
# 473              211             1        26.20   0.00     0.50        0.00
# 646              108             1        39.20   0.00     0.50        0.00
# ...              ...           ...          ...    ...      ...         ...
# 6339382          229             1        60.00   0.00     0.50       12.66
# 6339401          264             1        65.00   0.00     0.50       13.16
# 6339436          132             3         2.50   0.50     0.50        0.00
# 6339508          132             3         2.50   0.50     0.50        0.00
# 6339566          193             1         0.00   0.00     0.00        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 4                0.00                   0.30          4.80
# 6                0.00                   0.30          3.81
# 19               0.00                   0.30          6.80
# 473              0.00                   0.30         27.00
# 646              0.00                   0.30         40.00
# ...               ...                    ...           ...
# 6339382          0.00                   0.30         75.96
# 6339401          0.00                   0.30         78.96
# 6339436          0.00                   0.30          3.80
# 6339508          0.00                   0.30          3.80
# 6339566          0.00                   0.00          0.00
#
#          congestion_surcharge        date  day  month  year  duration_of_trip
# 4                        0.00  2020-01-01    1      1  2020              2.30
# 6                        0.00  2020-01-01    1      1  2020              0.07
# 19                       2.50  2020-01-01    1      1  2020              1.43
# 473                      0.00  2020-01-01    1      1  2020             33.85
# 646                      0.00  2020-01-01    1      1  2020             31.45
# ...                       ...         ...  ...    ...   ...               ...
# 6339382                  2.50  2020-01-31   31      1  2020              0.17
# 6339401                  0.00  2020-01-31   31      1  2020              0.05
# 6339436                  0.00  2020-01-31   31      1  2020              0.05
# 6339508                  0.00  2020-01-31   31      1  2020              1.05
# 6339566                  0.00  2020-01-31   31      1  2020              1.07
#
# [63382 rows x 23 columns]

# %% [markdown]
# #### *the trip distance zero is an error i am going to drop it*

# %%
df= df[df["trip_distance"]>0]

# %%
df["fare_amount"].describe()
# Out:
# count   6255907.00
# mean         12.38
# std          11.10
# min           0.00
# 25%           6.50
# 50%           9.00
# 75%          13.50
# max         575.00
# Name: fare_amount, dtype: float64

# %% [markdown]
# #### *we see paymnet amount to be zero which is not possible and is definitely a mistake , now according to the nyc taxi prices* ![Screenshot 2024-11-06 003211.png](data:image/png;base64,...)

# %%
df = df[df["fare_amount"]>3] # we have fixed the fare_amount at atleast fairvalue of 3$

# %% [markdown]
# #### *now we focus on extras column that focuses on the extar charges paid by the user on rush hours or overnight*

# %%
df["extra"].describe()
# Out:
# count   6217995.00
# mean          1.11
# std           1.25
# min           0.00
# 25%           0.00
# 50%           0.50
# 75%           2.50
# max         113.01
# Name: extra, dtype: float64

# %% [markdown]
# #### *i want to have only the values with extra less than or equal to 10$*

# %%
df = df[df["extra"]<10]

# %%
df.describe()
# Out:
#                 tpep_pickup_datetime          tpep_dropoff_datetime  \
# count                        6217987                        6217987
# mean   2020-01-17 04:00:21.994011904  2020-01-17 04:13:26.540897024
# min              2019-12-31 23:30:07            2020-01-01 00:00:55
# 25%              2020-01-09 17:42:06            2020-01-09 17:56:27
# 50%              2020-01-17 00:15:27            2020-01-17 00:28:02
# 75%              2020-01-24 18:37:47     2020-01-24 18:51:40.500000
# max              2020-01-31 23:58:25            2020-01-31 23:59:58
# std                              NaN                            NaN
#
#        passenger_count  trip_distance  payment_type  fare_amount      extra  \
# count       6217987.00     6217987.00    6217987.00   6217987.00 6217987.00
# mean              1.54           2.89          1.26        12.44       1.11
# min               1.00           0.01          1.00         3.50       0.00
# 25%               1.00           1.00          1.00         6.50       0.00
# 50%               1.00           1.60          1.00         9.00       0.50
# 75%               2.00           2.90          2.00        13.50       2.50
# max               9.00         211.70          4.00       575.00       9.50
# std               1.14           3.76          0.46        11.11       1.25
#
#          mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# count 6217987.00  6217987.00    6217987.00             6217987.00
# mean        0.50        2.21          0.33                   0.30
# min         0.00        0.00          0.00                   0.00
# 25%         0.50        0.00          0.00                   0.30
# 50%         0.50        1.96          0.00                   0.30
# 75%         0.50        2.86          0.00                   0.30
# max         6.80     1100.00        910.50                   0.30
# std         0.03        2.68          1.73                   0.00
#
#        total_amount  congestion_surcharge        day      month       year  \
# count    6217987.00            6217987.00 6217987.00 6217987.00 6217987.00
# mean          18.46                  2.33      16.57       1.00    2020.00
# min            1.60                  0.00       1.00       1.00    2019.00
# 25%           11.16                  2.50       9.00       1.00    2020.00
# 50%           14.30                  2.50      17.00       1.00    2020.00
# 75%           19.56                  2.50      24.00       1.00    2020.00
# max         1110.80                  2.75      31.00      12.00    2020.00
# std           13.82                  0.63       8.83       0.03       0.00
#
#        duration_of_trip
# count        6217987.00
# mean              13.08
# min                0.02
# 25%                6.47
# 50%               10.48
# 75%               16.65
# max              199.82
# std                9.78

# %%
new_df = df.shape[0]

# %%
old_df_shape = 6405008

# %%
(old_df_shape-new_df)/old_df_shape
# Out:
# 0.029199182889389053

# %% [markdown]
# #### *we lost only 2% of the data and also reduced from 2Gb to 829MB*

# %% [markdown]
# # **Visualisation**

# %% [markdown]
# ####Q1. *Average Rides Per Hour*

# %%
df.head()
# Out:
#   VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0     1.00  2020-01-01 00:28:15   2020-01-01 00:33:03             1.00
# 1     1.00  2020-01-01 00:35:39   2020-01-01 00:43:04             1.00
# 2     1.00  2020-01-01 00:47:41   2020-01-01 00:53:52             1.00
# 3     1.00  2020-01-01 00:55:23   2020-01-01 01:00:14             1.00
# 9     1.00  2020-01-01 00:29:01   2020-01-01 00:40:28             2.00
#
#    trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           1.20       1.00                  N          238          239
# 1           1.20       1.00                  N          239          238
# 2           0.60       1.00                  N          238          238
# 3           0.80       1.00                  N          238          151
# 9           0.70       1.00                  N          246           48
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         6.00   3.00     0.50        1.47          0.00
# 1             1         7.00   3.00     0.50        1.50          0.00
# 2             1         6.00   3.00     0.50        1.00          0.00
# 3             1         5.50   0.50     0.50        1.36          0.00
# 9             1         8.00   3.00     0.50        2.35          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge        date  day  \
# 0                   0.30         11.27                  2.50  2020-01-01    1
# 1                   0.30         12.30                  2.50  2020-01-01    1
# 2                   0.30         10.80                  2.50  2020-01-01    1
# 3                   0.30          8.16                  0.00  2020-01-01    1
# 9                   0.30         14.15                  2.50  2020-01-01    1
#
#    month  year  duration_of_trip  hr  weekday
# 0      1  2020              4.80   0        2
# 1      1  2020              7.42   0        2
# 2      1  2020              6.18   0        2
# 3      1  2020              4.85   0        2
# 9      1  2020             11.45   0        2

# %%
Vendor_per_hour = df.groupby(["hr","date"])["VendorID"].count()
total_rides = Vendor_per_hour.rename("No_Of_rides").reset_index()
hr_avg_rides_df = total_rides.groupby(["hr"])["No_Of_rides"].mean()

# %%
plt.figure(figsize=(10,4))
hr_avg_rides_df.plot(kind="bar")
plt.suptitle("Average Rides Per Hour")
plt.show()

# %% [markdown]
# ### *we can see subah ke 4 baje kam hi logo ki chul hai jane ki and sham ke 6 baje toh bhai bohoton ko jana hai🤣*

# %% [markdown]
# #### Q2. *Average rides per day*

# %%
Vendor_per_day = df.groupby(["day","date"])["VendorID"].count()
total_rides = Vendor_per_day.rename("No_Of_rides").reset_index()
day_avg_rides_df = total_rides.groupby(["day"])["No_Of_rides"].mean()
# day_avg_rides_df

# %%
plt.figure(figsize=(10,5))
day_avg_rides_df.plot(kind="bar")
plt.suptitle("Average Rides Per Day")
plt.show()

# %%
rides = df.pivot_table(index="date",columns="hr",values="VendorID",aggfunc="count")
rides
# Out:
# hr               0        1        2       3       4       5       6   \
# date
# 2019-12-31      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 2020-01-01 12923.00 14658.00 13132.00 9474.00 5975.00 2613.00 2126.00
# 2020-01-02  2231.00  1173.00   741.00  542.00  681.00 1432.00 3441.00
# 2020-01-03  3298.00  2108.00  1222.00  936.00  898.00 1418.00 3701.00
# 2020-01-04  6501.00  5218.00  3749.00 2745.00 1558.00 1095.00 1611.00
# 2020-01-05  8211.00  6670.00  5358.00 3615.00 2201.00 1119.00 1510.00
# 2020-01-06  2147.00  1091.00   778.00  488.00  784.00 1842.00 4670.00
# 2020-01-07  2529.00  1331.00   822.00  558.00  781.00 1790.00 4560.00
# 2020-01-08  3101.00  1660.00  1061.00  694.00  781.00 1656.00 4754.00
# 2020-01-09  3922.00  1945.00  1111.00  847.00  842.00 1736.00 4831.00
